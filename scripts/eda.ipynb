# %%
import pandas as pd

# Read the CSV file
df = pd.read_csv('../tweets.csv')

# Display the dataframe
df
# Out:
#            username                                               text
# 0       @DjokerNole  The GOAT of tennis\n\nsaid: "35 is the new 25....
# 1        @yacineMTB  kache (yacine) (KING OF DING)\n\n·\n1h\nsmalle...
# 2         @levelsio  Alibaba just released ReplaceAnything on Huggi...
# 3         @DrJimFan  Jim Fan\n\nChatbot Arena is a unique LLM bench...
# 4       @cto_junior  TDM (e/λ)\n\n·\n1h\nWhat's the easiest cloud p...
# 5        @yacineMTB  kache (yacine) (KING OF DING)\n\n·\n19m\nif ga...
# 6       @thesephist            Linus\n\nUsing LLMs to interpret LLMs 🥺
# 7       @NielsRogge  Niels Rogge\n\nSigLIP by\n@Google\nis now avai...
# 8            @paulg  Paul Graham\n\nHow to make it more entertainin...
# 9        @yacineMTB  kache (yacine) (KING OF DING)\n\nFound out abo...
# 10         @Nexuist  Andi 🇦🇱🇺🇦 (e/alb)\n\n"The internet is noisy an...
# 11  @EduardoSlonski  Eduardo Slonski\n\nThere's a very interesting ...
# ...
